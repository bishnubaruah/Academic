# %%
####################################
# Assignment No. : 7
# Date: 07/11/2025
# Name: Bishnu Prasad Baruah
# Roll No. : 256121007
# Email: b.baruah@iitg.ac.in
#####################################

# %% [markdown]
# ## Question 1

# %%
#RK4 METHOD
#k functions

import time

def kvalues(x,y,h,fun): #x:initial, y:initial, h:stepsize, fun:function
    a,b=x,y
    k1 = fun(a,b)

    a = x+h/2
    b = y+(k1*h)/2
    k2 = fun(a,b)

    a = x+h/2
    b = y+(k2*h)/2
    k3 =fun(a,b)

    a = x+h
    b = y+(k3*h)
    k4 = fun(a,b)
    
    return k1,k2,k3,k4

def nexty(y,k1,k2,k3,k4,h):              # y:initial
    return y+(h/6)*(k1+2*k2+2*k3+k4)

# %%
# derivative functions

def fun1(x,y):
    return -0.5*y

def fun2(x,y):
    return 4-0.3*y-0.1*y

h = 0.5 # step size

#k1,k2,k3,k4 = kvalues(0,4,0.5,fun1)
#nexty(4,k1,k2,k3,k4,0.5)

# %%
print(f"{'x_values':<10} {'k11':<7}{'k21':<7}{'k31':<7}{'k41':<7}{'y_1':<10} {'k12':<7}{'k22':<7}{'k32':<7}{'k42':<7}{'y_2'}")  # header line
print("-" * 90)

x = 1
x0 = 0
h = 0.3 #<=-----------
y10 = 4
y20 = 6
    
#rof = "{0:1.1f}       {1:1.2f}  {2:1.2f}  {3:1.2f}  {4:1.2f}  {5:1.4f}      {6:1.2f}   {7:1.2f}   {8:1.2f}   {9:1.2f}   {10:1.4f}"
#print(rof.format(x,k11,k21,k31,k41,y1,k12,k22,k32,k42,y2))

start_time = time.time()
while x<=10 :
    k11,k21,k31,k41 = kvalues(x0,y10,h,fun1)
    y1 = nexty(y10,k11,k21,k31,k41,h)
    
    k12,k22,k32,k42 = kvalues(x0,y20,h,fun2)
    y2 = nexty(y20,k12,k22,k32,k42,h)

    
    rowf = "{0:2.1f}       {1:1.2f}  {2:1.2f}  {3:1.2f}  {4:1.2f}  {5:1.4f}      {6:1.2f}   {7:1.2f}   {8:1.2f}   {9:1.2f}   {10:1.4f}"
    print(rowf.format(x,k11,k21,k31,k41,y1,k12,k22,k32,k42,y2))
    
    x+=h
    
    x0 = x0+h
    y10 = y1
    y20 = y2
    
end_time = time.time()
print(start_time)
print(end_time)
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")
# Out:
# x_values   k11    k21    k31    k41    y_1        k12    k22    k32    k42    y_2
# ------------------------------------------------------------------------------------------
# 1.0       -2.00  -1.85  -1.86  -1.72  3.4428      1.60   1.50   1.51   1.42   6.4523
# 1.3       -1.72  -1.59  -1.60  -1.48  2.9633      1.42   1.33   1.34   1.26   6.8535
# 1.6       -1.48  -1.37  -1.38  -1.27  2.5505      1.26   1.18   1.19   1.12   7.2093
# 1.9       -1.28  -1.18  -1.19  -1.10  2.1953      1.12   1.05   1.05   0.99   7.5249
# 2.2       -1.10  -1.02  -1.02  -0.94  1.8895      0.99   0.93   0.93   0.88   7.8048
# 2.5       -0.94  -0.87  -0.88  -0.81  1.6263      0.88   0.83   0.83   0.78   8.0530
# 2.8       -0.81  -0.75  -0.76  -0.70  1.3998      0.78   0.73   0.73   0.69   8.2732
# 3.1       -0.70  -0.65  -0.65  -0.60  1.2048      0.69   0.65   0.65   0.61   8.4684
# 3.4       -0.60  -0.56  -0.56  -0.52  1.0370      0.61   0.58   0.58   0.54   8.6416
# 3.7       -0.52  -0.48  -0.48  -0.45  0.8925      0.54   0.51   0.51   0.48   8.7952
# 4.0       -0.45  -0.41  -0.42  -0.38  0.7682      0.48   0.45   0.45   0.43   8.9315
# 4.3       -0.38  -0.36  -0.36  -0.33  0.6612      0.43   0.40   0.40   0.38   9.0523
# 4.6       -0.33  -0.31  -0.31  -0.28  0.5691      0.38   0.36   0.36   0.34   9.1595
# 4.9       -0.28  -0.26  -0.26  -0.24  0.4898      0.34   0.32   0.32   0.30   9.2545
# 5.2       -0.24  -0.23  -0.23  -0.21  0.4216      0.30   0.28   0.28   0.26   9.3388
# 5.5       -0.21  -0.19  -0.20  -0.18  0.3629      0.26   0.25   0.25   0.23   9.4136
# 5.8       -0.18  -0.17  -0.17  -0.16  0.3123      0.23   0.22   0.22   0.21   9.4799
# 6.1       -0.16  -0.14  -0.15  -0.13  0.2688      0.21   0.20   0.20   0.18   9.5387
# 6.4       -0.13  -0.12  -0.13  -0.12  0.2314      0.18   0.17   0.17   0.16   9.5909
# 6.7       -0.12  -0.11  -0.11  -0.10  0.1992      0.16   0.15   0.15   0.15   9.6371
# 7.0       -0.10  -0.09  -0.09  -0.09  0.1714      0.15   0.14   0.14   0.13   9.6782
# 7.3       -0.09  -0.08  -0.08  -0.07  0.1475      0.13   0.12   0.12   0.11   9.7146
# 7.6       -0.07  -0.07  -0.07  -0.06  0.1270      0.11   0.11   0.11   0.10   9.7468
# 7.9       -0.06  -0.06  -0.06  -0.05  0.1093      0.10   0.10   0.10   0.09   9.7755
# 8.2       -0.05  -0.05  -0.05  -0.05  0.0941      0.09   0.08   0.08   0.08   9.8009
# 8.5       -0.05  -0.04  -0.04  -0.04  0.0810      0.08   0.07   0.08   0.07   9.8234
# 8.8       -0.04  -0.04  -0.04  -0.03  0.0697      0.07   0.07   0.07   0.06   9.8433
# 9.1       -0.03  -0.03  -0.03  -0.03  0.0600      0.06   0.06   0.06   0.06   9.8611
# 9.4       -0.03  -0.03  -0.03  -0.03  0.0516      0.06   0.05   0.05   0.05   9.8768
# 9.7       -0.03  -0.02  -0.02  -0.02  0.0444      0.05   0.05   0.05   0.04   9.8907
# 1762420880.741
# 1762420880.748
# Elapsed time: 0.007000 seconds

# %%
print(f"{'x_values':<10} {'k11':<7}{'k21':<7}{'k31':<7}{'k41':<7}{'y_1':<10} {'k12':<7}{'k22':<7}{'k32':<7}{'k42':<7}{'y_2'}")  # header line
print("-" * 90)

x = 1
x0 = 0
h = 1.0 #<=-------
y10 = 4
y20 = 6
    
#rof = "{0:1.1f}       {1:1.2f}  {2:1.2f}  {3:1.2f}  {4:1.2f}  {5:1.4f}      {6:1.2f}   {7:1.2f}   {8:1.2f}   {9:1.2f}   {10:1.4f}"
#print(rof.format(x,k11,k21,k31,k41,y1,k12,k22,k32,k42,y2))

start_time = time.time()

while x<=10 :
    k11,k21,k31,k41 = kvalues(x0,y10,h,fun1)
    y1 = nexty(y10,k11,k21,k31,k41,h)
    
    k12,k22,k32,k42 = kvalues(x0,y20,h,fun2)
    y2 = nexty(y20,k12,k22,k32,k42,h)

    
    rowf = "{0:2.1f}       {1:1.2f}  {2:1.2f}  {3:1.2f}  {4:1.2f}  {5:1.4f}      {6:1.2f}   {7:1.2f}   {8:1.2f}   {9:1.2f}   {10:1.4f}"
    print(rowf.format(x,k11,k21,k31,k41,y1,k12,k22,k32,k42,y2))
    
    x+=h
    
    x0 = x0+h
    y10 = y1
    y20 = y2
    
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.6f} seconds")
# Out:
# x_values   k11    k21    k31    k41    y_1        k12    k22    k32    k42    y_2
# ------------------------------------------------------------------------------------------
# 1.0       -2.00  -1.50  -1.62  -1.19  2.4271      1.60   1.28   1.34   1.06   7.3184
# 2.0       -1.21  -0.91  -0.99  -0.72  1.4727      1.07   0.86   0.90   0.71   8.2023
# 3.0       -0.74  -0.55  -0.60  -0.44  0.8936      0.72   0.58   0.60   0.48   8.7948
# 4.0       -0.45  -0.34  -0.36  -0.27  0.5422      0.48   0.39   0.40   0.32   9.1920
# 5.0       -0.27  -0.20  -0.22  -0.16  0.3290      0.32   0.26   0.27   0.21   9.4583
# 6.0       -0.16  -0.12  -0.13  -0.10  0.1996      0.22   0.17   0.18   0.14   9.6369
# 7.0       -0.10  -0.07  -0.08  -0.06  0.1211      0.15   0.12   0.12   0.10   9.7566
# 8.0       -0.06  -0.05  -0.05  -0.04  0.0735      0.10   0.08   0.08   0.06   9.8368
# 9.0       -0.04  -0.03  -0.03  -0.02  0.0446      0.07   0.05   0.05   0.04   9.8906
# 10.0       -0.02  -0.02  -0.02  -0.01  0.0271      0.04   0.04   0.04   0.03   9.9267
# Elapsed time: 0.002000 seconds

# %% [markdown]
# ## Question 2

# %% [markdown]
# ## Boundary condition #1

# %%
import numpy as np

k = 0.01
step = 0.5
T_air = 20
T_0 = 40
T_10 = 200
n = int(10 / step) - 1 #number of segments

#RHS matrix
c = k*step**2*T_air
for i in range(n):
    b_mat[i] = c
b_mat[0] += T_0
b_mat[-1] += T_10

# Coefficient matrix (tridiagonal)
a_mat = np.zeros((n,n))
d = 2+k*step**2

for i in range(n):               
    a_mat[i, i] = d              # main diagonal
    if i > 0:
        a_mat[i, i-1] = -1       # lower diagonal
    if i < n-1:
        a_mat[i, i+1] = -1 

L = np.identity(n)
U = np.zeros((n,n))
for i in range(n):
    U[i,i] = a_mat[i, i]
    if i < n-1 :
        U[i,i+1] = a_mat[i,i+1]
        
mat = np.copy(a_mat)    #------======----decomposition----====-----
for k in range(1,n):
    L[k,k-1] = np.round((mat[k,k-1])/mat[k-1,k-1], 3)
    mat[k,k] = np.round(mat[k,k] - L[k,k-1]*mat[k-1,k], 3)
    U[k,k] = mat[k,k]

r_mat = np.copy(b_mat)
for k in range(1,n):     #forward substitution
    r_mat[k] = np.round(r_mat[k] - L[k,k-1] * r_mat[k-1],3)

T_mat = np.zeros((n,1))  #Backward substitution
T_mat[n-1] = np.round(r_mat[n-1]/U[n-1,n-1],3)
for k in range(n-2,-1,-1):
    T_mat[k] = np.round((r_mat[k] - U[k,k+1]*T_mat[k+1])/U[k,k], 3)

print("Number of interior nodes =", n)
print("Temperature vector T:\n", T_mat)
# Out:
# Number of interior nodes = 19
# Temperature vector T:
#  [[ 46.19 ]
#  [ 52.446]
#  [ 58.791]
#  [ 65.289]
#  [ 71.963]
#  [ 78.745]
#  [ 85.73 ]
#  [ 92.816]
#  [ 99.995]
#  [107.465]
#  [115.192]
#  [123.203]
#  [131.589]
#  [140.244]
#  [149.332]
#  [158.789]
#  [168.549]
#  [178.535]
#  [189.025]]

# %% [markdown]
# ## Boundary condition #2

# %%
import numpy as np

k = 0.01
step = 0.5
T_air = 20
T_0 = 40
T_10 = 200
n = int(10 / step)          # instead of int(10 / step) - 1

#RHS matrix
c = k*step**2*T_air
b_mat = np.full((n,1), c)
b_mat[-1] += T_10    # right boundary condition


# Coefficient matrix (tridiagonal)
a_mat = np.zeros((n,n))
d = 2+k*step**2

for i in range(n):               
    a_mat[i, i] = d              # main diagonal
    if i > 0:
        a_mat[i, i-1] = -1       # lower diagonal
    if i < n-1:
        a_mat[i, i+1] = -1
a_mat[0, 1] = -2                  # upper diagonal -2 instead of -1 to incorpotate Neumann condition 


L = np.identity(n)
U = np.zeros((n,n))
for i in range(n):
    U[i,i] = a_mat[i, i]
    if i < n-1 :
        U[i,i+1] = a_mat[i,i+1]
        
mat = np.copy(a_mat)    #------======----decomposition----====-----
for k in range(1,n):
    L[k,k-1] = np.round((mat[k,k-1])/mat[k-1,k-1], 3)
    mat[k,k] = np.round(mat[k,k] - L[k,k-1]*mat[k-1,k], 3)
    U[k,k] = mat[k,k]

r_mat = np.copy(b_mat)
for k in range(1,n):     #forward substitution
    r_mat[k] = np.round(r_mat[k] - L[k,k-1] * r_mat[k-1],3)

T_mat = np.zeros((n,1))  #Backward substitution
T_mat[n-1] = np.round(r_mat[n-1]/U[n-1,n-1],3)
for k in range(n-2,-1,-1):
    T_mat[k] = np.round((r_mat[k] - U[k,k+1]*T_mat[k+1])/U[k,k], 3)

print("Number of interior nodes =", n)
print("Temperature vector T:\n", T_mat)
# Out:
# Number of interior nodes = 20
# Temperature vector T:
#  [[142.24 ]
#  [142.393]
#  [142.888]
#  [143.62 ]
#  [144.595]
#  [145.818]
#  [147.297]
#  [149.041]
#  [151.062]
#  [153.373]
#  [155.989]
#  [158.929]
#  [162.212]
#  [165.861]
#  [169.734]
#  [173.848]
#  [178.391]
#  [183.218]
#  [188.349]
#  [193.994]]

# %% [markdown]
# ## Question 3

# %%
n = 5 # grid points
Told = np.zeros((n,n)) # grid creation
lmbda = 1.5 #overrelaxation

Tnew = np.copy(Temp)
for i in range(6):
    for j in range(6):
        Tnew[i ,j] =  Told[i+1 , j] + Told[i-1 , j] + Told[i , j+1] + Told[1 ,j-1]
        Tnew[i,j] = lmbda*Tnew[i,j] + (1-lmbda) * Told[i,j]
T
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 8
#       6 for i in range(6):
#       7     for j in range(6):
# ----> 8         Tnew[i ,j] =  Told[i+1 , j] + Told[i-1 , j] + Told[i , j+1] + Told[1 ,j-1]
#       9         Tnew[i,j] = lmbda*Tnew[i,j] + (1-lmbda) * Told[i,j]
#      10 T
#
# IndexError: index 5 is out of bounds for axis 1 with size 5
